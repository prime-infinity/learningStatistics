# %%
import pandas as pd
import numpy as np
# Set the maximum column width to None to display the entire contents of the column
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv("tmdb_5000_movies.csv")
df
# Out:
#          budget  \
# 0     237000000
# 1     300000000
# 2     245000000
# 3     250000000
# 4     260000000
# ...         ...
# 4798     220000
# 4799       9000
# 4800          0
# 4801          0
# 4802          0
#
#                                                                                                                                       genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]
# 1                                             [{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}]
# 2                                               [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 80, "name": "Crime"}]
# 3                   [{"id": 28, "name": "Action"}, {"id": 80, "name": "Crime"}, {"id": 18, "name": "Drama"}, {"id": 53, "name": "Thriller"}]
# ...

# %%
df.head()
# Out:
#       budget  \
# 0  237000000
# 1  300000000
# 2  245000000
# 3  250000000
# 4  260000000
#
#                                                                                                                                    genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]
# 1                                          [{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}]
# 2                                            [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 80, "name": "Crime"}]
# 3                [{"id": 28, "name": "Action"}, {"id": 80, "name": "Crime"}, {"id": 18, "name": "Drama"}, {"id": 53, "name": "Thriller"}]
# 4                                 [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 878, "name": "Science Fiction"}]
#
# ...

# %%
df.revenue.describe()
# Out:
# count    4.803000e+03
# mean     8.226064e+07
# std      1.628571e+08
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.917000e+07
# 75%      9.291719e+07
# max      2.787965e+09
# Name: revenue, dtype: float64

# %%
df['revenue_mln'] = df['revenue'].apply(lambda x: x/1000000)
df.revenue_mln.describe()
# Out:
# count    4803.000000
# mean       82.260639
# std       162.857101
# min         0.000000
# 25%         0.000000
# 50%        19.170001
# 75%        92.917187
# max      2787.965087
# Name: revenue_mln, dtype: float64

# %%
df.head()
# Out:
#       budget  \
# 0  237000000
# 1  300000000
# 2  245000000
# 3  250000000
# 4  260000000
#
#                                                                                                                                    genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]
# 1                                          [{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}]
# 2                                            [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 80, "name": "Crime"}]
# 3                [{"id": 28, "name": "Action"}, {"id": 80, "name": "Crime"}, {"id": 18, "name": "Drama"}, {"id": 53, "name": "Thriller"}]
# 4                                 [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 878, "name": "Science Fiction"}]
#
# ...

# %%
df.loc[df.revenue_mln == df.revenue_mln.max()]
# Out:
#       budget  \
# 0  237000000
#
#                                                                                                                                    genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
# ...

# %%
df.loc[df.popularity == df.popularity.max()]
# Out:
#        budget  \
# 546  74000000
#
#                                                                                                                                 genres  \
# 546  [{"id": 10751, "name": "Family"}, {"id": 16, "name": "Animation"}, {"id": 12, "name": "Adventure"}, {"id": 35, "name": "Comedy"}]
#
#                          homepage      id  \
# 546  http://www.minionsmovie.com/  211672
#
#                                                                                                                                                                                                                                            keywords  \
# 546  [{"id": 3487, "name": "assistant"}, {"id": 179430, "name": "aftercreditsstinger"}, {"id": 179431, "name": "duringcreditsstinger"}, {"id": 189481, "name": "evil mastermind"}, {"id": 190999, "name": "minions"}, {"id": 209714, "name": "3d"}]
#
#     original_language original_title  \
# 546                en        Minions
#
# ...

# %% [markdown]
# # using normal z score to detect outliers

# %%
df.revenue_mln.describe() #we are dealing with price only
# Out:
# count    4803.000000
# mean       82.260639
# std       162.857101
# min         0.000000
# 25%         0.000000
# 50%        19.170001
# 75%        92.917187
# max      2787.965087
# Name: revenue_mln, dtype: float64

# %%
_, mean, std, *_ = df.revenue_mln.describe()

# %%
mean,std
# Out:
# (82.26063865167637, 162.85710094282624)

# %%
import seaborn as sn

# %%
sn.histplot(df.revenue_mln, kde=True) #just messing around
# Out:
# <AxesSubplot:xlabel='revenue_mln', ylabel='Count'>

# %%
def get_z_score(value,mean,std):
    return (value-mean)/std

# %%
#create another column in the dataframe called zscore and store it

# %%
df["z_score"] = df.revenue_mln.apply(lambda x: get_z_score(x,mean,std))

# %%
df.head()
# Out:
#       budget  \
# 0  237000000
# 1  300000000
# 2  245000000
# 3  250000000
# 4  260000000
#
#                                                                                                                                    genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]
# 1                                          [{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}]
# 2                                            [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 80, "name": "Crime"}]
# 3                [{"id": 28, "name": "Action"}, {"id": 80, "name": "Crime"}, {"id": 18, "name": "Drama"}, {"id": 53, "name": "Thriller"}]
# 4                                 [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 878, "name": "Science Fiction"}]
#
# ...

# %%
#outliers based on zscore
df[df.z_score < 3]
# Out:
#          budget  \
# 4     260000000
# 10    270000000
# 13    255000000
# 15    225000000
# 21    200000000
# ...         ...
# 4798     220000
# 4799       9000
# 4800          0
# 4801          0
# 4802          0
#
#                                                                                                                                       genres  \
# 4                                    [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 878, "name": "Science Fiction"}]
# 10    [{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}, {"id": 878, "name": "Science Fiction"}]
# 13                                            [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 37, "name": "Western"}]
# 15                                         [{"id": 12, "name": "Adventure"}, {"id": 10751, "name": "Family"}, {"id": 14, "name": "Fantasy"}]
# ...

# %%
#but as you can see, many valuable and legit datasets has been removed
#this is not a bad value to remove unless it is altering the values of the rest of our dataset, there are other values that may
#be outliers, but because this values affects the mean more than them, we might not be detecting them

# %% [markdown]
# # usnig modified zscore to detect outliers

# %%
def get_mad(s):
    median = np.median(s)
    diff = abs(s - median)
    MAD = np.median(diff)
    return MAD

# %%
MAD = get_mad(df.revenue_mln)
median = np.median(df.revenue_mln)
MAD,median
# Out:
# (19.170001, 19.170001)

# %%
def get_modified_z_score(x,median,MAD):
    return 0.6745 *(x-median)/MAD

# %%
get_modified_z_score(2787.965087,median,MAD)
# Out:
# 97.4205627588126

# %%
df["mod_z_score"] = df.revenue_mln.apply(lambda x: get_modified_z_score(x,median,MAD))
df.head()
# Out:
#       budget  \
# 0  237000000
# 1  300000000
# 2  245000000
# 3  250000000
# 4  260000000
#
#                                                                                                                                    genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]
# 1                                          [{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}]
# 2                                            [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 80, "name": "Crime"}]
# 3                [{"id": 28, "name": "Action"}, {"id": 80, "name": "Crime"}, {"id": 18, "name": "Drama"}, {"id": 53, "name": "Thriller"}]
# 4                                 [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 878, "name": "Science Fiction"}]
#
# ...

# %%
#outliers based on mod_z_score
df[df.mod_z_score>3.5]
# Out:
#          budget  \
# 0     237000000
# 1     300000000
# 2     245000000
# 3     250000000
# 4     260000000
# ...         ...
# 4441     858000
# 4467     777000
# 4496      60000
# 4577      15000
# 4586   35000000
#
#                                                                                                                                       genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]
# 1                                             [{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}]
# 2                                               [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 80, "name": "Crime"}]
# 3                   [{"id": 28, "name": "Action"}, {"id": 80, "name": "Crime"}, {"id": 18, "name": "Drama"}, {"id": 53, "name": "Thriller"}]
# ...

# %%
df[df.mod_z_score<=3.5] #outliers wth modified zscore
# Out:
#          budget  \
# 13    255000000
# 83     27000000
# 97     15000000
# 135   150000000
# 141   150000000
# ...         ...
# 4798     220000
# 4799       9000
# 4800          0
# 4801          0
# 4802          0
#
#                                                                                                                                                                   genres  \
# 13                                                                        [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 37, "name": "Western"}]
# 83                             [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 878, "name": "Science Fiction"}, {"id": 10749, "name": "Romance"}]
# 97    [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 18, "name": "Drama"}, {"id": 27, "name": "Horror"}, {"id": 878, "name": "Science Fiction"}]
# ...

# %%
df.overview #try to make the details show fully
# Out:
# 0                                                                                                                                                                                                                                                                                                                  In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.
# 1                                                                                                                                                                                                                                                                                                                 Captain Barbossa, long believed to be dead, has come back to life and is headed to the edge of the Earth with Will Turner and Elizabeth Swann. But nothing is quite as it seems.
# ...
